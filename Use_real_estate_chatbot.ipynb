# %% [markdown]
# # Make sure you are connected to T4 GPU

# %% [markdown]
# # **Clone the Chatbot Repository **

# %%
# !git clone "https://github.com/Inequilazitive/Real_estate_chatbot.git"
# Out:
# Cloning into 'Real_estate_chatbot'...
# remote: Enumerating objects: 52, done.
# remote: Counting objects: 100% (52/52), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 52 (delta 19), reused 52 (delta 19), pack-reused 0 (from 0)
# Receiving objects: 100% (52/52), 22.79 KiB | 22.79 MiB/s, done.
# Resolving deltas: 100% (19/19), done.

# %% [markdown]
# # Move to the folder directory

# %%
# %cd '/content/Real_estate_chatbot'
# Out:
# /content/Real_estate_chatbot

# %% [markdown]
# # Set Your Hugging Face Token as environment variable- Make sure you are granted access the LLama 3.2 repo

# %%
import os
os.environ["HF_TOKEN"] = "<Your HF access token with access to llama 3.2-3B-Instruct model>"

# %% [markdown]
# # Run the app.py, it will give you the link to the local deployment of the chatbot, please proceed to that link and access the chatbot

# %%
# !python3 app.py
